# %%
# System znaczników morfosyntaktycznych w korpusie IPI PAN :
# http://nlp.ipipan.waw.pl/CORPUS/znakowanie.pdf
# http://nkjp.pl/poliqarp/help/plse2.html

# %%
import numpy as np
import pandas as pd

import morfeusz2
from IPython.display import display, Markdown

# %%
def filter_empty_strings(str_list):
    return list(filter(None, str_list))

def index_items(str_list):
    indices = []
    for i in range(len(str_list)):
        indices.append(i)
    return indices

def get_list_item(str_list, item_idx):
    return str_list[item_idx]

# %%
data_train_exp = pd.read_csv("../../data/outputs/feature_engineering/train/expected.csv")

# %%
base_items_df = data_train_exp.copy()
base_items_df["text_split"] = base_items_df["FixedOutput"].apply(str.split)
base_items_df["text_split"] = base_items_df["text_split"].apply(filter_empty_strings)
base_items_df["item_index"] = base_items_df["text_split"].apply(index_items)
base_items_df = base_items_df.explode("item_index").reset_index(drop=True)
base_items_df["item"] = base_items_df.apply(lambda x: get_list_item(x.text_split, x.item_index), axis=1)

# %%
base_items_df
# Out:
#                 FileId                                        FixedOutput  \
# 0       wikinews228460  w wywiadzie dla polski jarosław kaczyński podk...
# 1       wikinews228460  w wywiadzie dla polski jarosław kaczyński podk...
# 2       wikinews228460  w wywiadzie dla polski jarosław kaczyński podk...
# 3       wikinews228460  w wywiadzie dla polski jarosław kaczyński podk...
# 4       wikinews228460  w wywiadzie dla polski jarosław kaczyński podk...
# ...                ...                                                ...
# 184458  wikinews195323  29 lutego na wydziale matematyki i informatyki...
# 184459  wikinews195323  29 lutego na wydziale matematyki i informatyki...
# 184460  wikinews195323  29 lutego na wydziale matematyki i informatyki...
# 184461  wikinews195323  29 lutego na wydziale matematyki i informatyki...
# 184462  wikinews195323  29 lutego na wydziale matematyki i informatyki...
#
#                                                text_split item_index  \
# 0       [w, wywiadzie, dla, polski, jarosław, kaczyńsk...          0
# 1       [w, wywiadzie, dla, polski, jarosław, kaczyńsk...          1
# 2       [w, wywiadzie, dla, polski, jarosław, kaczyńsk...          2
# 3       [w, wywiadzie, dla, polski, jarosław, kaczyńsk...          3
# 4       [w, wywiadzie, dla, polski, jarosław, kaczyńsk...          4
# ...                                                   ...        ...
# 184458  [29, lutego, na, wydziale, matematyki, i, info...        179
# 184459  [29, lutego, na, wydziale, matematyki, i, info...        180
# 184460  [29, lutego, na, wydziale, matematyki, i, info...        181
# 184461  [29, lutego, na, wydziale, matematyki, i, info...        182
# 184462  [29, lutego, na, wydziale, matematyki, i, info...        183
#
#              item
# 0               w
# 1       wywiadzie
# 2             dla
# 3          polski
# 4        jarosław
# ...           ...
# 184458    chopina
# 184459         30
# 184460      wstęp
# 184461      wolny
# 184462          .
#
# [184463 rows x 5 columns]

# %% [markdown]
# ### Adding columns with preceding and following words

# %%
prev_items_df = base_items_df.merge(base_items_df[["item_index", "item"]].shift(1).rename({
    "item": "prev_item",
    "item_index": "prev_item_index"
}, axis=1), left_index=True, right_index=True)

items_df = prev_items_df.merge(base_items_df[["item_index", "item"]].shift(-1).rename({
    "item": "next_item",
    "item_index": "next_item_index"
}, axis=1), left_index=True, right_index=True)

prev_cond_mask = (items_df["item_index"]==0)
next_cond_mask = (items_df["next_item_index"]==0)

items_df.loc[prev_cond_mask, 'prev_item'] = np.nan
items_df.loc[next_cond_mask, 'next_item'] = np.nan

items_df = items_df.drop(["prev_item_index", "next_item_index", "text_split"], axis=1)

# %%
items_df
# Out:
#                 FileId                                        FixedOutput  \
# 0       wikinews228460  w wywiadzie dla polski jarosław kaczyński podk...
# 1       wikinews228460  w wywiadzie dla polski jarosław kaczyński podk...
# 2       wikinews228460  w wywiadzie dla polski jarosław kaczyński podk...
# 3       wikinews228460  w wywiadzie dla polski jarosław kaczyński podk...
# 4       wikinews228460  w wywiadzie dla polski jarosław kaczyński podk...
# ...                ...                                                ...
# 184458  wikinews195323  29 lutego na wydziale matematyki i informatyki...
# 184459  wikinews195323  29 lutego na wydziale matematyki i informatyki...
# 184460  wikinews195323  29 lutego na wydziale matematyki i informatyki...
# 184461  wikinews195323  29 lutego na wydziale matematyki i informatyki...
# 184462  wikinews195323  29 lutego na wydziale matematyki i informatyki...
#
#        item_index       item  prev_item  next_item
# 0               0          w        NaN  wywiadzie
# 1               1  wywiadzie          w        dla
# 2               2        dla  wywiadzie     polski
# 3               3     polski        dla   jarosław
# 4               4   jarosław     polski  kaczyński
# ...           ...        ...        ...        ...
# 184458        179    chopina          .         30
# 184459        180         30    chopina      wstęp
# 184460        181      wstęp         30      wolny
# 184461        182      wolny      wstęp          .
# 184462        183          .      wolny        NaN
#
# [184463 rows x 6 columns]

# %% [markdown]
# ### Morphological analysis application

# %%
morf = morfeusz2.Morfeusz(analyse=True, generate=False, expand_tags=False)

morf_df = items_df[["item"]].copy()
morf_df["morf_analysis"] = morf_df["item"].apply(morf.analyse)

# %%
# extracting relevant information from the output
morf_df = morf_df.explode("morf_analysis").reset_index(drop=True)
morf_df['morf_analysis'] = morf_df['morf_analysis'].str[2]
morf_df["tag"] = morf_df['morf_analysis'].str[2]
morf_df = morf_df.drop('morf_analysis', axis=1)

# %%
morf_df
# Out:
#              item                          tag
# 0               w                prep:acc:nwok
# 1               w                prep:loc:nwok
# 2       wywiadzie              subst:sg:loc:m3
# 3       wywiadzie              subst:sg:voc:m3
# 4             dla                     prep:gen
# ...           ...                          ...
# 374663      wolny            adj:sg:acc:m3:pos
# 374664      wolny  adj:sg:nom.voc:m1.m2.m3:pos
# 374665      wolny            adj:sg:acc:m3:pos
# 374666      wolny  adj:sg:nom.voc:m1.m2.m3:pos
# 374667          .                       interp
#
# [374668 rows x 2 columns]

# %%
# checking the words unrecognized by Morpheusz2 (verification whether data cleaning process was correct)
df = morf_df.copy()
ignored_items = df.loc[df["tag"]=="ign"]["item"].value_counts()

for item in ignored_items.index:
    print(item)
    
ignored_items_df = ignored_items.reset_index().rename({"item": "count", "index": "word"}, axis=1)
ignored_items_df.to_csv("../../data/outputs/feature_engineering/ignored_items_df.csv", index=False)

# drop unrecognized items (listed below)
df=df.loc[df["tag"]!="ign"]
# Out:
# r
# np
# the
# godz
# of
# tzw
# św
# ks
# wikimedia
# moze
# prof
# itp
# fukushima
# tvn24
# n
# wikinews
# itd
# commons
# byc
# f
# world
# madridistas
# mari
# bokeria
# hearts
# geniuses
# gsl
# season
# leenockiem
# celticowi
# blizzconie
# kongdoo
# streamując
# asl
# mongiem
# bestem
# hintem
# nakamura
# zgłos
# publikajach
# freak
# poimprezowe
# gesellschaft
# zur
# verfolgung
# urheberrechtsverletzungen
# vimeo
# hostuje
# friedsam
# sixtusa
# alexandra
# priessnitz
# viral
# award
# opsec
# security
# sixtus
# ciurlok
# myslovitz
# festivalu
# madridismo
# label
# halt
# flies
# drosophila
# heterosomów
# umaru
# styli
# dochnala
# lichtensteinie
# nfz
# nauman
# bi
# transseksulnych
# zrodla
# believe
# loud
# proprosic
# dzieki
# mrm
# próchnikowej
# believeoutloud
# savar
# dhaki
# khaleda
# zia
# pkpp
# fzz
# yaradua
# okah
# qpczikw
# cove
# finance
# gpw
# ubs
# caib
# unicredit
# kotlinowski
# kracika
# kaszulanis
# balamutha
# rona
# zydówka
# netzach
# belissarius
# infoboks
# pomylka
# zydowskiego
# wilczebłota
# hosera
# nossig
# zyd
# niger
# kwaśniewki
# stavanger
# steinar
# ege
# schmiedlov
# kanepi
# ryst
# kaią
# peer
# szachar
# siniakov
# kateina
# torró
# witthft
# ein
# smitkov
# tereza
# koukalovej
# helicopters
# h225
# eurocoptera
# as532
# klrze
# cougara
# vidalia
# kwalifikantce
# niginie
# abduraimovej
# johnny
# bieleckikarola
# jachlewski
# c64
# rozwinałem
# możeliwe
# żłobkowo
# frode
# alis
# hagen
# gilles
# niculescu
# buy
# corriere
# della
# blackout
# skuteczym
# 230v
# miesiąch
# 0v
# stokczy
# fedorą
# joyeux
# matematyczno
# keen
# swps
# adrew
# szewacha
# imposible
# mowi
# szah
# hamid
# niescislosc
# dauda
# hamida
# shaha
# shah
# haguenau
# hiszpanskiej
# zhuyin
# mowią
# haut
# martinbutton
# molsheim
# fegersheim
# offenburg
# wyroznione
# minutes
# polapie
# mcgaw
# wygladaja
# poswiecil
# zastapiona
# protokananjeski
# pakuzujących
# pracyję
# miesiecy
# guy
# walks
# kananjeskiego
# into
# people
# punktow
# battle
# wyroznic
# xbox
# portable
# rownowaznych
# overdose
# dreamcatcher
# todd
# heiligenstein
# plobsheim
# wikireporterom
# wikireporterów
# skangur
# arbeit
# malaheedh
# ascher
# mahadher
# khafji
# theatre
# hasama
# stewart
# aliego
# gavin
# clooneya
# haggisa
# peacomm
# badreddin
# beijing
# kontkiewicz
# sadah
# gehsperre
# shabab
# muomineen
# macht
# frei
# yochanan
# ąderko
# teologtak
# ifuw
# forak
# therese
# hedwig
# hainitz
# henriette
# teschendorf
# porządkowedefinicja
# victor
# fried
# regenwalde
# kassel
# hesja
# ęgeniusz
# aleph
# geb
# trwaja
# eitan
# rafi
# byblos
# wciaz
# lahti
# ikomputer
# adamat
# nowosci
# tremendo
# mówie
# spisuja
# mysli
# róznorodnosc
# jednaksze
# dmitrijew
# theobalda
# adamt
# marencjaodmianę
# vise
# marencjo
# vinciego
# colea
# cortony
# downing
# messiny
# rębiewski
# ganders
# et22
# pokladzie
# xxxxxxxxxxxxx
# wogóle
# domius
# grzexs
# softdevcon
# jedej
# hryniszak
# groovy
# jednkowe
# transformatorowo
# grails
# installation
# caching
# byol
# grzexsjak
# st44
# ducciu
# grzexsczy
# bouninsegnim
# misc
# ewntualnie
# buoninsegni
# niedociąnięć
# tea
# room
# wikiprojektu
# glen
# theobald
# jednoczesnie
# ladem
# densill
# nevilla
# niedostepna
# uzurpowac
# angli
# okreslonej
# pogladowo
# ptrtlr
# ejski
# podzial
# dluzszego
# kanaan
# ugarit
# protokananejski
# dotarla
# zas
# resztal
# lasalle
# aurtis
# panstw
# zaznacone
# prarie
# hiuppo
# lampard
# sancho
# oppama
# carraghera
# smyrna
# cyd
# zama
# vehicle
# hislop
# setiego
# joy
# ev
# ultra
# hypermini
# shaka
# gourmet
# kenwyne
# terry
# whitley
# litzmannstadt
# przylinkowania
# eu43
# sacharę
# auxois
# semur
# nc
# waglowskiego
# sznownych
# sanadera
# poczodzi
# poprosze
# nieokreslonego
# pierwiasta
# dziekuje
# duellis
# c12
# protu
# offk
# któzy
# minutory
# brajter
# vloga
# ivo
# machinima
# kelly
# armancon
# elfhelma
# celsiusza
# brou
# pawmakprzydałoby
# dame
# mustafar29
# tallis
# notre
# tallisa
# g8
# tonego
# pektoralny
# eksarchia
# epaminondas
# korkoneas
# grigoropulosa
# kostatsa
# karamanlisa
# pasok
# islamsy
# bresse
# powiedzić
# bourg
# lets
# podadnik
# winokourow
# winokurow
# mombasa
# lightcraft
# kemyd
# giorgio
# gru
# poznaiu
# jogischesem
# jogichesa
# patricia
# ledesma
# guilliem
# tlaloca
# akselroda
# encylkopedią
# iztapalapa
# mohylek
# szblonem
# hardt
# socjalzdrajców
# kautzkich
# myspace
# industry
# swóją
# pezentować
# powermacintosh
# felicitas
# nagin
# parafrazowo
# orelan
# katrinę
# romank
# kpjasem
# win95
# winokurowa
# s99pl
# ergma
# based
# ppc
# równierz
# dyskietkowe
# kotek20
# stanislovas
# liutkeviczius
# ene
# tymczosowo
# boston9
# pawmakandrzei111
# wyłonionoby
# kuzmanovic
# menagerem
# zdravko
# cold
# jillian
# dejoseph
# dick
# goose
# mahoney
# duljaj
# kovacevic
# evan
# bourne
# miz
# awesome
# tomaszb84
# smackdown
# aktulane
# estrack
# nenad
# dragutinovic
# ivica
# jericho
# popchięty
# js
# milosz
# mkf
# liscie
# zawodnikow
# shelton
# 0x1ffb23p
# benjamin
# googl
# rosterze
# ecw
# merge
# połącze
# blunt
# roy
# christine
# reprezentatnów
# ditlenku
# mellon
# phoenixa
# lander
# mro
# jovanovic
# norcia
# soerensen
# krstajic
# a330
# sharif
# sheikh
# abdirahman
# carrie
# carrieego
# tsang
# hung
# hassan
# shabelleh
# dhexe
# wai
# brancion
# beledweyne
# aden
# grandmont
# loire
# tsvangirai
# kukz15
# kukiz15
# sane
# morelon
# cheung
# kurpś
# hiraan
# gtp
# mladen
# lines
# mudallad
# ivanovic
# branislav
# avramov
# vlada
# arm9
# zigić
# lazović
# warsiawy
# cache
# stack
# gpio
# sheikha
# busacca
# tarbunka
# howlwadag
# kulury
# kurpiowskia
# elektrowózet
# chengdu
# imie
# massacre
# seeds
# nawaf
# wplywu
# podpisal
# motif
# osaadzić
# lgplv2
# wakeboardingowej
# szczureq
# common
# environment
# sco
# fujitsu
# kilwaterbordzista
# kilwaterbording
# zalegalizownaiu
# kde
# motifa
# revenue
# sharing
# source
# bsd
# upolityczninia
# cerkwii
# musawi
# finding
# homosexual
# plavi
# henri
# odelvis
# dominico
# speek
# zagladac
# yoandri
# daz
# carmenate
# keibir
# guttierez
# torres
# aldazabal
# skomentowac
# wydarzylo
# pavel
# wrzucal
# pimienta
# rolando
# jurquin
# despaigne
# raydel
# corrales
# watpliwości
# durruty
# aware
# camejo
# watpilym
# mowia
# homoioi
# vlado
# petković
# dejan
# bojović
# janić
# andrija
# gerić
# podraanin
# agoge
# samardzić
# marrou
# branimir
# perić
# nikić
# starović
# snchez
# bozhulev
# oriol
# pouto
# panad
# garfiki
# podniesiania
# pedoseksualizmem
# lgbtqia
# opendns
# linkedin
# iac
# foursquare
# lg
# bł
# etsy
# aol
# ipeku
# number
# studies
# been
# published
# decade
# reporting
# that
# act
# adolescents
# were
# aseksualizmem
# wyciagania
# mówia
# odcników
# świetości
# wrzesnia
# wielośc
# kilkudzisięciu
# znikna
# rownież
# jasnosci
# chomiksów
# blogoslawionych
# zastapiony
# dokładym
# swiety
# pzredkongergacyjny
# usuniecia
# myslę
# zynga
# mzopw
# panther
# paypal
# kinsey
# altima
# pisu
# gate
# rekacji
# cow
# rpm
# tmpfs
# hotspot
# networkmanager
# dragonegg
# gcc
# llvm
# selinux
# booleans
# krb5
# credential
# caches
# clojure
# eula
# sysvinit
# systemd
# openshift
# origin
# procps
# ng
# backendu
# hawkey
# libsolv
# sat
# spherical
# fesco
# fabus
# szczegolowych
# deibert
# majaca
# okladki
# uzywamy
# artykulacy
# enya
# uzywanie
# joymaster
# naforach
# angieslkich
# przewinal
# wnioskow
# balaz
# rzeczywiscie
# osobiscie
# wode
# division
# marriottu
# archiasza
# isokratesa
# author
# skopence
# expose
# mykiel
# solver
# shin
# senyszyn
# kori
# grove
# emkaffe
# mpc
# j2
# zbędy
# belushi
# prozpozycja
# opp
# pre
# paidów
# łęson
# apokaliptyk
# któej
# estem
# slane
# minimal
# artu
# atysta
# przydorządkowania
# gomes
# cybiny
# muzaffarabad
# islambadu
# muzaffarabadu
# lahore
# crauford
# wspinaczkowiczów
# uszby
# rudoportu
# opr
# muy
# bien
# roystona
# drenthe
# bernabeu
# borja
# penas
# zmpg
# wilhelmshaven
# lpg
# zambrze
# ntw
# wlkp
# suffolk
# quo
# vadis
# trimmer
# anthonym
# bartleyem
# francescę
# viertelem
# repertory
# ensa
# falun
# gre
# zostawil
# zrobil
# kangasniemi
# siltala
# tuukka
# anttila
# bl
# matsushita
# battery
# okołozenitalnym
# sodano
# hoserem
# usgs
# sendai
# kimiego
# rikknena
# jrme
# dambrosio
# romaina
# grosjeana
# sergio
# qing
# hua
# naraina
# karthikeyana
# f112
# jensona
# tapio
# shumov
# kunnari
# kwon
# breezy
# badger
# lts
# dapper
# edgy
# fawn
# canonical
# fedorę
# irc
# shipit
# berruto
# khalaf
# szebabami
# socjolingwistyczne
# boszniacka
# boszniaka
# tolę
# aniol
# haha
# wlodzimierza
# polonizowac
# nastepuje
# ślazak
# więć
# spoloszczanie
# georg
# h1n1
# skasowalem
# wrz
# boszniak
# wytnięte
# tymbardziej
# użyszkodników
# soulscythe
# before
# ill
# uzystkania
# boczniacy
# dostawiac
# odroznienia
# kopirajt
# berasategui
# garincha
# zamorra
# kobayashi
# 2a
# kulturalno
# sadosiu
# sadosia
# sadoś
# francorchamps
# webber
# vettel
# raikkonen
# rosberg
# grosjean
# mclaren
# wbc
# raikkonenem
# grosjeanem
# lotusa
# beenhakkerowi
# zysmana
# delitzsch
# thale
# menziesa
# wernigerode
# hanoveru
# giampaolo
# ziggy
# byrdem
# dokladni
# 90tych
# pilkarzy
# pelego
# siedlaro
# wiktorynlista
# zszedl
# kliknalem
# zyjacych
# zejda
# spike
# stabilo
# antyprzemocowej
# ekologiczno
# chrisem
# jadłodzielnia
# ocelari
# trinec
# emic
# 1983r
# korean
# hazzard
# ridickiem
# bowe
# tysonem
# ruizem
# pistulka
# szwedkowskizgłoszone
# knack
# niemickiej
# rafid
# alwan
# janabi
# curveball
# rumsfeld
# curveballa
# tylera
# drumhellera
# carlą
# bruni
# zdjeciem
# lc1
# fg
# barratt
# giennadij
# zarja
# fashion
# posmykiewicz
# społecznikkandydatura
# fundacjafenomen
# jekaterynburgu
# jakow
# buckingham
# kbe
# compress
# unhcr
# chamenei
# sajed
# macerata
# randstad
# roeselare
# cska
# asseco
# resovia
# vfb
# frieddrichshafen
# hypo
# tirol
# bled
# marche
# panathinaikos
# moszarekat
# olympiacos
# ptc
# telecoms
# cellular
# information
# service
# hoesjna
# arabija
# ahmadinażeda
# khatamiego
# ahmadineżada
# termij
# securities
# cantu
# zastapic
# maelstrom
# undp
# cieżko
# hpi
# więszkosci
# siękonkretnie
# czepialstwo
# wrl
# wrs
# iłowajsku
# slowo
# asab
# grabiszyńska
# tendecyjny
# krzysiumed
# oskarzenia
# wzajemnuych
# socjalistyczno
# think
# ari
# vatanen
# indrzejczyka
# stavrosa
# dimasa
# aegis
# comfort
# trinita
# powiedzialo
# dossena
# prosba
# moglbym
# wpisac
# tytulow
# dilorian
# keriewem
# ogladac
# japonskich
# epizodow
# mielibyscie
# ipku
# imp
# pokemonów
# pokestronę
# poke
# bulbapedia
# alvea
# cnbc
# itvn
# chę
# dexter
# californication
# grabiszyńskiej
# interneuci
# przestepstwo
# bundeslidze
# pank
# wikipedyjnymi
# moglby
# duza
# roznic
# mlodziezowki
# moge
# jestesmy
# glupio
# brzmialo
# powoluje
# mlodziezowka
# dolaczylismy
# liczaca
# mlodziezowa
# panuja
# obiemai
# bedac
# mlodych
# dolaczanie
# wiekszosc
# mlodziezowej
# zapisalem
# miesiace
# piastu
# fesitwalu
# geocachingową
# geocachingowe
# geocachingiem
# gagauzi
# polcard
# artefact
# gorzelik
# comapny
# schetynę
# chwalstwo
# owskiego
# berec
# rtl
# siarhiejem
# martynauem
# wyrózniła
# mapping
# wkz
# ksiązkowych
# zakaria
# jamal
# eot
# ławrywiańca
# schwarzschlida
# nieistotona
# rosajakie
# odderstartowała
# czesem
# uzsadnienie
# mundry
# pozdro
# fiorentiny
# grałw
# noob
# napisałes
# mś2006
# acf
# luco
# genoa
# stenebo
# performancemedia
# netsprint
# goldi
# jrs
# dark
# richeze
# milram
# agustina
# microsd
# henryego
# riberyego
# abidala
# jorge
# larriona
# saha
# apache
# eclipse
# rights
# eben
# moglen
# perens
# tridgell
# dibona
# wikireportera
# brandona
# stafforda
# phipps
# doug
# suna
# mysql
# qualcomm
# patrzac
# takze
# porownujac
# likwodowane
# thierry
# maniche
# krisztina
# delgado
# ashley
# lapardzie
# naftohaz
# arbela
# duhuk
# babacan
# koksal
# toptan
# cemil
# cicek
# hostowaną
# pauleta
# wikię
# amy
# kinrepok
# bundy91
# waclawdzieciol
# transformato
# florent
# malouda
# fabien
# barthez
# deco
# ktora
# ponizej
# przerobic
# spadafora
# colina
# dzialem
# podejsc
# naleza
# prowokowal
# wojne
# geos
# m38
# wullf
# crackera
# cracker
# repubblica
# dicka
# rustu
# recber
# nfl
# alvin
# gajadhur
# orlando
# travel
# huawei
# mpix
# mp3
# bluetooth
# cheneya
# vodafone
# opieralo
# pslv
# ilosci
# zawierac
# haslem
# okreslona
# uzywa
# okreslenia
# skaly
# praktyczcie
# wikipedystapsjulek
# satish
# dawan
# czerwony64
# kirowohradzkim
# orbwiki107
# cyclingu
# budcud
# gabukow
# 137kilo
# poltwór
# late
# maps
# heho
# fokker
# szymkencie
# complex
# ecotech
# umcsu
# mcarthur
# viduka
# udinese
# grosso
# lucasa
# neilla
# guus
# hiddink
# kawalerowicza
# nortomu
# czupkiewicza
# kaukazoidzi
# kapoidzi
# australoidzi
# biasutti
# wtm
# rzemomo
# wiekszość
# ogole
# yakhub
# dyskusja12
# lichtensteinu
# ey2012
# ricka
# perryego
# walls
# schwarzer
# strzele
# wypiąstkąwał
# mvo
# massimino
# feustel
# wide
# wfpc2
# nm
# netię
# onephone
# pierszej
# kartęsprawdzone
# tele2001
# prefix
# uke
# materazziego
# alehandro
# poray
# alehandroporaygmail
# mass
# podyskutujmyhasło
# błedów
# brescianio
# gianluigi
# cahill
# materazzi
# bresciano
# huntsville
# frankfurter
# berliner
# sistema
# gminoruchów
# italikowie
# wenetowie
# ilirijski
# wenetach
# illirowie
# ilirowie
# wenetami
# protoceltów
# more
# upu
# village
# drum
# kollektiv
# slavka
# slavko
# ołeksandra
# ramex
# pykspa
# secure
# kaspersky
# szałbydałtów
# szałbydałci
# majderdrut
# dubstep
# modeselektor
# catzn
# dubsknit
# dogz
# cls
# wax
# encore
# glasse
# lex
# novika
# harper
# bshosa
# dio
# akaone
# mooryc
# liebing
# seb
# eltron
# beachboys
# optymist
# naphta
# audioriver
# trentemller
# sven
# vth
# kalkbrenner
# vitalic
# grunsfeld
# megan
# kociewia
# cest
# belge
# stapleton
# patrik
# sinkewitz
# bernucci
# vuelta
# espana
# cavendisha
# ciolek
# isnieją
# smiać
# yann
# arthus
# sylvie
# derdacka
# bautista
# morera
# jaimego
# ortiego
# ruiza
# valencii
# gerolsteiner
# gaspol
# powtawania
# food
# circuit
# stryker
# didżala
# chafik
# tomq
# bolkow86
# susan
# clemens
# kurówką
# mbabane
# suazi
# financial
# pepenadores
# ismail
# haniyeh
# tuninter
# agency
# dżerba
# palese
# puglia
# alitalia
# punta
# raisi
# klementyńskiej
# eca
# hot
# bird
# nss
# bombs
# sambyka
# andybrandt
# bordaczow
# srode
# champs
# katii
# bronskiej
# webranej
# ave
# visones
# compostela
# myśliwieckiej
# gordiejew
# timofiej
# rihanna
# kaszkawal
# reloaded
# sprzedazy
# cart
# wkońcu
# tyg
# zal
# bonitta
# monbat
# fob
# ganascia
# minurcat
# obruci
# noora
# pokerstars
# rusol
# pysiekm
# andżelikę
# andżeliki
# andżeliką
# lebiedżka
# lebiedżki
# sultana
# farrella
# nyt
# rodhe
# kalinichenko
# niesmacznyj
# jaber
# zaid
# szweczenko
# kaliniczenki
# ammena
# hawsawi
# dokhiego
# khathran
# ghamdi
# rotan
# saud
# kariri
# małgocha
# przebiegao
# fizykaa
# leidyi
# sipisova
# vide
# timeu
# marako
# bhutan
# frauncuski
# urzedowym
# jaubree
# tamazight
# average
# histori
# trade
# poors
# nasdaq
# area
# leading
# napiszmała
# nedops
# mev
# piii
# kthaara
# rodrguez
# kostasem
# karamanlisem
# sarkozyego
# gilgen
# edelmann
# xaver
# gakushuin
# zprp
# muhlematter
# wzrastajacej
# brdzo
# malejacy
# głowne
# 3razy
# thoku
# iitate
# yasuyuki
# muramatsu
# ewro
# spichiger
# yonghap
# wonsan
# takeo
# kawamura
# taepondong
# gallen
# eit
# supramolekularnej
# seitz
# michalitch
# ursula
# guantanamo
# ecce
# kore
# różych
# dlugotrwalej
# obrazen
# migatu
# póżniej
# konstatncinie
# piador
# mangalore
# ils
# boening
# zootechnkiem
# social
# starscream
# dgse
# ll
# lyanne
# noelia
# poka
# plastusia
# colargol
# patents
# floss
# esp
# umsc
# uemcees
# zmarl
# osama
# prostacykliny
# szarapowej
# physicians
# chest
# yusek
# wymyslił
# wikilinków
# 1914r
# zdjęciamimario58
# ytek
# ana
# ivanović
# qatar
# kuzniecowa
# republicain
# mauresmo
# hingis
# vaidisova
# czakwetadze
# clijsters
# samanthą
# carą
# champions
# sereną
# iar
# lest
# fanini
# mnemiopsis
# gerais
# esserath
# śp
# mediawiki
# wikistics
# linz
# farrah
# fawcett
# mazovii
# mazovia
# dynatek
# roels
# tondar
# fateh
# akbar
# salehi
# mohammadi
# golpajegani
# męźczyzn
# widzialem
# literke
# zaporożscy
# napisac
# gythachciałabym
# mahmeda
# galerieji
# trains
# spółdzielnianego
# piewszy
# wzieliście
# heidler
# carrefour
# rózni
# wikipedi
# xmikolajx
# december
# june
# archives
# administration
# slacka
# swpawel
# betty
# hrasnova
# masters
# berlinu
# usaina
# zremiksowanego
# teatralno
# fireshow
# edu
# vibez
# cathedral
# suv
# rft
# backstoppers
# grande
# vitesse
# transrapid
# zeng
# computational
# intelligence
# brisbane
# anchorage
# neurodynamikę
# neuronaukę
# neuroinżynierię
# tianzi
# xin
# yao
# southern
# guang
# cloud
# hou
# fonobaru
# after
# pzl
# fsc
# wyboy
# yazidi
# belacqua
# marisy
# coulter
# potter
# ieee
# sea
# rekacje
# used
# moissan
# fluorkowe
# teolognie
# wachowskialuzję
# teologz
# wachowskispotkałem
# tex
# encja
# mtm
# encje
# commonly
# meaning
# clipperze
# breaking
# wipurw
# adobe
# quarkxpress
# quarkowym
# daroooo
# indesigna
# brosenspv
# passenger
# vessel
# brosennie
# pti

# %%
# checking the punctuation marks recognized by Morpheusz2
df.loc[df["tag"]=="interp"]["item"].value_counts()
# Out:
# .    10372
# ,    10069
# -     2422
# :      897
# ?      768
# !      114
# Name: item, dtype: int64

# %%
tmp = df['tag'].str.split(':', 1, expand=True).rename({0: 'grammatical_class', 1:'grammatical_categories'}, axis=1)

whitelist=['nom','gen','dat','acc','inst','loc','voc','imperf','perf']  # morphemes of cases and aspects
pat = r'\b(?:{})\b'.format('|'.join(whitelist))
tmp['grammatical_categories']=tmp['grammatical_categories'].str.findall('(' + pat + ')').str.join('.')
df = pd.concat([df, tmp], axis=1)

# %%
df
# Out:
#              item                          tag grammatical_class  \
# 0               w                prep:acc:nwok              prep
# 1               w                prep:loc:nwok              prep
# 2       wywiadzie              subst:sg:loc:m3             subst
# 3       wywiadzie              subst:sg:voc:m3             subst
# 4             dla                     prep:gen              prep
# ...           ...                          ...               ...
# 374663      wolny            adj:sg:acc:m3:pos               adj
# 374664      wolny  adj:sg:nom.voc:m1.m2.m3:pos               adj
# 374665      wolny            adj:sg:acc:m3:pos               adj
# 374666      wolny  adj:sg:nom.voc:m1.m2.m3:pos               adj
# 374667          .                       interp            interp
#
#        grammatical_categories
# 0                         acc
# 1                         loc
# 2                         loc
# 3                         voc
# 4                         gen
# ...                       ...
# 374663                    acc
# 374664                nom.voc
# 374665                    acc
# 374666                nom.voc
# 374667                   None
#
# [367411 rows x 4 columns]

# %%
grammatical_categories_dict = df.drop_duplicates(subset=["item", "grammatical_class"]).sort_values(["item", "grammatical_class"], ascending=True).groupby(['item'])['grammatical_class'].apply(';'.join).reset_index()

# %%
grammatical_categories_dict
# Out:
#            item grammatical_class
# 0             !            interp
# 1             ,            interp
# 2             -            interp
# 3             .            interp
# 4             0               dig
# ...         ...               ...
# 31276   żądanie         ger;subst
# 31277  żądaniem         ger;subst
# 31278     żądać               inf
# 31279     żądał             praet
# 31280     żądań         ger;subst
#
# [31281 rows x 2 columns]

# %% [markdown]
# ### Concatenate enriched frame with morphological analysis results

# %%
res_df = items_df.merge(grammatical_categories_dict, on="item", how="left").rename({"grammatical_class": "item_classes"}, axis=1)
res_df = res_df.merge(grammatical_categories_dict, left_on="prev_item", right_on="item", how="left").rename({"grammatical_class": "prev_item_classes"}, axis=1)
res_df = res_df.merge(grammatical_categories_dict, left_on="next_item", right_on="item", how="left").rename({"grammatical_class": "next_item_classes"}, axis=1)
res_df = res_df.drop(["item", "item_y"], axis=1).rename({"item_x": "item"}, axis=1)

# %% [markdown]
# ### Check the morphological environment of punctuation marks

# %%
punctuations_df = res_df.loc[res_df["item_classes"] == "interp"].reset_index()
punctuations_df = punctuations_df[['FileId', 'FixedOutput', 'item', 'prev_item', 'prev_item_classes', 'next_item', 'next_item_classes']]

punctuations_df
# Out:
#                FileId                                        FixedOutput item  \
# 0      wikinews228460  w wywiadzie dla polski jarosław kaczyński podk...    ,
# 1      wikinews228460  w wywiadzie dla polski jarosław kaczyński podk...    .
# 2      wikinews228460  w wywiadzie dla polski jarosław kaczyński podk...    ,
# 3      wikinews228460  w wywiadzie dla polski jarosław kaczyński podk...    -
# 4      wikinews228460  w wywiadzie dla polski jarosław kaczyński podk...    ,
# ...               ...                                                ...  ...
# 24637  wikinews195323  29 lutego na wydziale matematyki i informatyki...    ,
# 24638  wikinews195323  29 lutego na wydziale matematyki i informatyki...    ,
# 24639  wikinews195323  29 lutego na wydziale matematyki i informatyki...    .
# 24640  wikinews195323  29 lutego na wydziale matematyki i informatyki...    .
# 24641  wikinews195323  29 lutego na wydziale matematyki i informatyki...    .
#
#               prev_item prev_item_classes         next_item  \
# 0            podkreślił             praet                że
# 1               państwa             subst                to
# 2              wszystko     adj;adv;subst                co
# 3            powiedzieć               inf      odpowiedział
# 4          odpowiedział             praet               gdy
# ...                 ...               ...               ...
# 24637     społecznością             subst  administrowaniem
# 24638  administrowaniem               ger               jak
# 24639       wikipediami             subst            wykład
# 24640                ul             subst           chopina
# 24641             wolny         adj;subst               NaN
#
#               next_item_classes
# 0                     comp;part
# 1      adj;comp;part;pred;subst
# 2          comp;part;prep;subst
# 3                         praet
# 4                      adv;comp
# ...                         ...
# 24637                       ger
# 24638  adv;comp;conj;prep;subst
# 24639                     subst
# 24640                     subst
# 24641                       NaN
#
# [24642 rows x 7 columns]

# %%
# re-check the target classes balance
punctuations_df["item"].value_counts()
# Out:
# .    10372
# ,    10069
# -     2422
# :      897
# ?      768
# !      114
# Name: item, dtype: int64

# %%
target_classes = [',', '.', '-', ':', '?', '!']

# %%
# check the items preceeding individual punctuation marks
res_dict = {}
for punct_symb in target_classes:
    display(Markdown(f"#### Punctuation mark: \"{punct_symb}\""))
    df = punctuations_df.loc[punctuations_df["item"] == punct_symb].reset_index()
    display(pd.DataFrame(df["prev_item"].value_counts()).head(20))
# Out:
# #### Punctuation mark: ","
#               prev_item
# się                  91
# to                   74
# tym                  59
# powiedział           56
# roku                 54
# 1                    40
# osób                 38
# tego                 32
# również              31
# 2                    31
# dodał                31
# tak                  30
# polski               27
# stwierdził           26
# uważa                24
# osoby                22
# zapowiedział         22
# jednak               21
# wynika               21
# nadzieję             21
# #### Punctuation mark: "."
#         prev_item
# m             151
# r             135
# in            129
# roku          108
# ok             90
# np             66
# tys            63
# osób           55
# ul             48
# godz           46
# ds             43
# proc           37
# lat            37
# polski         29
# kraju          25
# św             24
# tzw            24
# pracy          24
# ks             24
# w              21
# #### Punctuation mark: "-"
#             prev_item
# al                 33
# polsko             21
# 2                  15
# roku               12
# 0                  12
# pis                12
# e                  11
# sts                10
# północno           10
# covid               9
# polski              9
# 4                   9
# 30                  8
# sars                8
# południowo          8
# kujawsko            7
# 21                  7
# 1                   7
# sms                 7
# biało               7
# #### Punctuation mark: ":"
#            prev_item
# wikipedia         22
# 20                17
# 3                 15
# 16                14
# zgłasza           14
# 18                14
# 15                13
# 13                12
# 1                 12
# 10                 9
# 12                 9
# się                9
# 2                  8
# 17                 8
# 19                 8
# to                 8
# in                 8
# 11                 8
# 14                 8
# 22                 7
# #### Punctuation mark: "?"
#           prev_item
# nie               9
# chodzi            7
# artykule          6
# co                5
# źródła            5
# było              5
# zaciekle          4
# to                4
# prawda            4
# dlaczego          4
# błąd              4
# w                 3
# żart              3
# jest              3
# być               3
# rzeszy            3
# napisać           3
# nazwa             3
# polski            3
# roku              3
# #### Punctuation mark: "!"
#              prev_item
# pozdrawiam           5
# się                  4
# konta                4
# witam                3
# dalej                2
# błąd                 2
# być                  2
# wstyd                2
# słowa                1
# proste               1
# zupa                 1
# świętych             1
# wikipedyści          1
# grekiem              1
# gołębie              1
# roboty               1
# heca                 1
# art                  1
# zapraszamy           1
# jak                  1

# %%
# check the items following individual punctuation marks
res_dict = {}
for punct_symb in target_classes:
    display(Markdown(f"#### Punctuation mark: \"{punct_symb}\""))
    df = punctuations_df.loc[punctuations_df["item"] == punct_symb].reset_index()
    display(pd.DataFrame(df["next_item"].value_counts()).head(20))
# Out:
# #### Punctuation mark: ","
#         next_item
# że           1356
# a             575
# w             317
# ale           245
# który         240
# które         224
# która         160
# to            160
# co            120
# jak           118
# bo            107
# by             99
# na             92
# aby            92
# czy            87
# którzy         87
# nie            82
# gdzie          80
# z              79
# iż             65
# #### Punctuation mark: "."
#          next_item
# w              700
# na             203
# in             139
# nie            120
# to             115
# po             115
# z              113
# do             109
# według          87
# jak             77
# o               70
# a               69
# od              59
# jest            58
# czy             55
# podczas         42
# jednak          42
# i               42
# pl              42
# co              42
# #### Punctuation mark: "-"
#               next_item
# powiedział          117
# w                    38
# stwierdził           32
# mówił                28
# dodał                26
# poinformował         24
# to                   21
# nie                  21
# letni                19
# u                    18
# napisał              16
# mówi                 16
# jak                  16
# 3                    15
# 1                    14
# i                    14
# na                   13
# a                    13
# jest                 12
# 19                   12
# #### Punctuation mark: ":"
#         next_item
# 00             59
# 30             20
# zgłoś          19
# w              19
# 1              18
# 2              10
# 0               9
# polska          7
# 3               7
# nie             7
# wiki            6
# 24              6
# 25              6
# 15              6
# to              6
# z               5
# jest            5
# 04              5
# 20              5
# 31              4
# #### Punctuation mark: "?"
#           next_item
# czy              31
# w                28
# to               23
# nie              22
# a                19
# bo               12
# na               10
# z                10
# tak              10
# dlaczego         10
# przecież         10
# jak               9
# no                9
# jeśli             9
# co                9
# i                 8
# chyba             8
# zgłasza           7
# może              6
# ja                6
# #### Punctuation mark: "!"
#              next_item
# w                    6
# co                   5
# należy               4
# .                    4
# do                   3
# ,                    3
# czy                  2
# to                   2
# nie                  2
# jak                  2
# ja                   2
# zaprasza             1
# czyli                1
# ewangelia            1
# spolecznosc          1
# zamiast              1
# core                 1
# łodzi                1
# jestem               1
# oraz                 1

# %%
# Conclusions:
# 1. there is a need to handle abbreviations within the baseline model
# 2. data cleaning seems to be ok
# 3. certainty: abbreviations for dots, two-part expressions for dashes,
